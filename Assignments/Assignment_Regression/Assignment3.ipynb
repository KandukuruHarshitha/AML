# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
df=pd.read_csv(r"C:\Users\bda\Desktop\AML\data\income_data.csv")
df
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# ..          ...       ...        ...
# 493         494  5.249209   4.568705
# 494         495  3.471799   2.535002
# 495         496  6.087610   4.397451
# 496         497  3.440847   2.070664
# 497         498  4.530545   3.710193
#
# [498 rows x 3 columns]

# %%
x=df[["income"]]
y=df[["happiness"]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0])
print("y_actual:", y_test.values)
print("y_predicted:", y_pred)
# Out:
# Intercept: [0.14170387]
# Slope: [0.7247687]
# y_actual: [[4.75416839]
#  [4.1596093 ]
#  [2.29570014]
#  [2.31155424]
#  [2.86127444]
#  [1.96563593]
#  [4.57080113]
#  [4.00453774]
#  [1.46061633]
#  [3.73794161]
#  [4.83350643]
#  [3.05738784]
#  [3.06760945]
#  [2.78424454]
#  [2.15584332]
#  [2.96216821]
#  [2.23344058]
#  [6.29910126]
#  [1.83980201]
#  [2.96195666]
#  [2.33627603]
#  [4.2452156 ]
#  [2.11513648]
#  [1.30848726]
#  [4.71966533]
#  [0.77128657]
#  [2.67988732]
#  [4.98525493]
#  [3.80429886]
#  [4.8266027 ]
#  [0.69845996]
#  [3.04079729]
#  [2.39167752]
#  [4.5993734 ]
#  [3.73056996]
#  [3.70343793]
#  [0.96852733]
#  [3.45310274]
#  [1.41666106]
#  [1.41022957]
#  [5.83619666]
#  [4.3284171 ]
#  [5.9142477 ]
#  [5.3139569 ]
#  [2.31448898]
#  [2.00904646]
#  [2.57505486]
#  [3.02072445]
#  [2.20098217]
#  [0.26604366]
#  [3.98112774]
#  [3.22747217]
#  [5.26547896]
#  [4.93304409]
#  [2.66611603]
#  [4.30728842]
#  [3.99041589]
#  [4.56870456]
# ...

# %%
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean Squared Error: 0.590146394343082
# Mean Absolute Error: 0.6269683431894553
# R-squared: 0.6662585264303965
# RMSE: 0.768209863476825

# %%
import matplotlib.pyplot as plt
 
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Marks')
plt.ylabel('Predicted Marks')
plt.title('Actual vs Predicted Marks')
plt.show()

# %%
residuals = y_test - y_pred
plt.scatter(y_pred, residuals, color='green')
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Predicted Marks')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
df=pd.read_csv(r"C:\Users\bda\Desktop\AML\data\Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=df[["YearsExperience"]]
y=df[["Salary"]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0])
print("y_actual:", y_test.values)
print("y_predicted:", y_pred)
# Out:
# Intercept: [25321.58301178]
# Slope: [9423.81532303]
# y_actual: [[112635.]
#  [ 67938.]
#  [113812.]
#  [ 83088.]
#  [ 64445.]
#  [ 57189.]]
# y_predicted: [[115790.21011287]
#  [ 71498.27809463]
#  [102596.86866063]
#  [ 75267.80422384]
#  [ 55477.79204548]
#  [ 60189.69970699]]

# %%
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean Squared Error: 49830096.85590839
# Mean Absolute Error: 6286.453830757749
# R-squared: 0.9024461774180497
# RMSE: 7059.04362190151

# %%
plt.scatter(x_train, y_train, color='blue', label='Training Data')
plt.scatter(x_test, y_test, color='orange', label='Testing Data')
plt.plot(x_test, y_pred, color='red', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.legend()
plt.show()

# %%
experience = pd.DataFrame([[7.5]], columns=["YearsExperience"])
# Ensure we get a scalar value even if predict returns a 2D array
predicted_salary = model.predict(experience).ravel()[0]
print(f"Predicted Salary for 7.5 years of experience: {predicted_salary:.2f}")
# Out:
# Predicted Salary for 7.5 years of experience: 96000.20
