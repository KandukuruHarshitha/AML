# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
df=pd.read_csv(r"C:\Users\bda\Desktop\AML\data\Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=df[["YearsExperience"]]
y=df[["Salary"]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model=make_pipeline(StandardScaler(), RidgeCV(alphas=[0.1, 1.0, 10.0]))

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('ridgecv', RidgeCV(alphas=[0.1, 1.0, 10.0]))])

# %%
ridge_model = model.named_steps['ridgecv']
print(f"Best alpha value: {ridge_model.alpha_}")
# Out:
# Best alpha value: 0.1

# %%
#error metrics
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# Mean Squared Error: 49948555.96597085
# Mean Absolute Error: 6276.678088721407
# R-squared: 0.9022142665903492
# RMSE: 7067.429233177425

# %%
# Mean Squared Error: 49830096.85590839
# Mean Absolute Error: 6286.453830757749
# R-squared: 0.9024461774180497
# RMSE: 7059.04362190151

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge

# %%
x=np.array([[1,0],[2,13],[3,22],[4,27],[5,36]])
y=np.array([40,48,57,65,74])
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
model=Ridge(alpha=1.0)
model.fit(x_scaled,y)
# Out:
# Ridge()

# %%
print("Interrupt",model.intercept_)
# Out:
# Interrupt 56.8

# %%
print("Standardized Coeffeient:",model.coef_)
# Out:
# Standardized Coeffeient: [5.8068681  5.11233726]

# %%
# Standardized Coeffeient: [8.26866972 3.62919783] for alpha=0.1
